# %%
from gcp_client import GCPClient

# %%
client = GCPClient()

# %%
image_data = client.download('sample/00000013_005.png')

# %%
from IPython.display import display, Image
import io

# %%
image = io.BytesIO(image_data)

# %%
display(Image(image.read()))
